# %%
# Out:
# 📂 Analisando 286 máscaras... aguarde.
# ----------------------------------------
# 📊 RESUMO DO DIAGNÓSTICO
# ----------------------------------------
# Tipos de arquivos encontrados: {'RGB (3D)': 286}
#
# 🎨 AS 10 CORES MAIS COMUNS (Formato: Cor -> Quantas imagens têm essa cor):
#    👉 Cor: (0, 0, 0) 	(Aparece em pixels de várias imagens)
#    👉 Cor: (61, 61, 245) 	(Aparece em pixels de várias imagens)
#    👉 Cor: (221, 255, 51) 	(Aparece em pixels de várias imagens)
# ----------------------------------------
